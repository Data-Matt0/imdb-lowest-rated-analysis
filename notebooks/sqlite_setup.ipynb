# %%
from google.colab import drive
drive.mount('/content/drive')


import os
import sqlite3

base_path = '/content/drive/MyDrive/IMDB_Data/filtered/'
db_path = '/content/drive/MyDrive/IMDB_Data/imdb_filtered.db'

csv_files = {
    'movies': os.path.join(base_path, 'merged_movies.csv'),
    'principals': os.path.join(base_path, 'principals_filtered.csv'),
    'names': os.path.join(base_path, 'names_filtered.csv')
}


import pandas as pd

conn = sqlite3.connect(db_path)

for table_name, path in csv_files.items():
    print(f"🔄 Loading {table_name} from {path}")
    df = pd.read_csv(path)
    df.to_sql(table_name, conn, if_exists='replace', index=False)

print("✅ All filtered CSVs loaded into SQLite.")


def show_schema(table):
    return pd.read_sql(f"PRAGMA table_info({table});", conn)

show_schema('movies')



pd.read_sql("SELECT * FROM movies LIMIT 5;", conn)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🔄 Loading movies from /content/drive/MyDrive/IMDB_Data/filtered/merged_movies.csv
# 🔄 Loading principals from /content/drive/MyDrive/IMDB_Data/filtered/principals_filtered.csv
# 🔄 Loading names from /content/drive/MyDrive/IMDB_Data/filtered/names_filtered.csv
# ✅ All filtered CSVs loaded into SQLite.
#       tconst titleType                    primaryTitle  \
# 0  tt0035423     movie                  Kate & Leopold
# 1  tt0038687     movie              Let There Be Light
# 2  tt0040559     movie  The Machine to Kill Bad People
# 3  tt0042210     movie                          Utopia
# 4  tt0042539     movie              Halls of Montezuma
#
#                 originalTitle  isAdult  startYear endYear  runtimeMinutes  \
# 0              Kate & Leopold      0.0     2001.0    None           118.0
# ...
